# %% [markdown]
# QUESTION 1)Replace the NaN values with correct value.And justify why you have chosen the same.

# %%
#The ways to Replace the NaN values are:
#OPTION 1:Delete the entire Row(Drop the missing values)
#OPTION 2:consider this as a semi supervised,create a model,so that we can predict the missing values
#OPTION 3:Replace the missing values with central tendency-Mean,Median,Mode
#OPTION 4:Respective to the problem,have to replace the missing values

# %%
#OPTION 1:

# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
#RESULT:If we using this option ,we have to delete the entire Rows,so,there is a chance to loss the
#        data's in the dataset.It is a wrong method.

# %%
#OPTION 2:If we using this for this dataset,it will consider as Non placed students are salaried.
#RESULT  :So,it is a wrong method.

# %%
#OPTION 3:

# %%
dataset["salary"].fillna(dataset["salary"].mean(),inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  \
# ...

# %%
#RESULT  :This method also  consider as Non placed students are salaried.So,it is also a wrong method.

# %%
#OPTION 4:

# %%
dataset["salary"].fillna(0,inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#CONCLUSION:In this method,we filled 0 irrespecive of NaN values for the Not placed students.
#       Without data loss,filled the missing values.So,this is a correct method of replacing the Nan values.

# %% [markdown]
# #Question NO 2:HOW MANY OF THEM ARE NOT PLACED?

# %%
value_counts=dataset["status"].value_counts()["Not Placed"]
print(value_counts)
# Out:
# 67

# %%
#RESULT:67 students are NOT PLACED

# %% [markdown]
# #QUESTION 3:Find the reason for non placement from the dataset?

# %%
#RESULT:In all test,average of 70%(as per the median result) mark scored students only placed, other students are not plced

# %% [markdown]
# #QUESTION 4:What kind of relation between salary and mba_p?

# %%
correlation=dataset["salary"].corr(dataset["mba_p"])

# %%
correlation
# Out:
# 0.13982273892615563

# %%
#Result:Zero correlation of between salary and mba_p.

# %% [markdown]
# #QUESTION 5:What specialization getting minimum salary?

# %%
min_salary=dataset.loc[dataset["salary"].idxmin()]["specialisation"]

# %%
min_salary
# Out:
# 'Mkt&HR'

# %%
#RESULT:Mkt&Fin specialization is getting minimum salary.

# %% [markdown]
# #QUESTION 6:How many of them getting above 500000 salary?:

# %%
calc=dataset[dataset["salary"]>500000]

# %%
calc
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 119    120      M   60.8  Central  68.40  Central  Commerce      64.6
# 150    151      M   71.0  Central  58.66  Central   Science      58.0
# 177    178      F   73.0  Central  97.00   Others  Commerce      79.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 150   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 177  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %%
calc.shape[0]
# Out:
# 3

# %%
#RESULT:3 students getting above 500000 salary.

# %% [markdown]
# #QUESTION 7:Test the Analysis of Variance between etest_p and mba_p at significance level 5%.(Hypothesis testing)

# %%
import scipy.stats as stats
stats.f_oneway(dataset["etest_p"],dataset["mba_p"])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
#statement: whether There is significant difference between etest_p and mba_p ?
#Ho:There is no significant difference between etest_p and mba_p
#H1:There is significant difference between etest_p and mba_p
#p value=4.67 which is not <0.05
#condition :p<0.05,REJECT NULL HYPOTHESIS,ACCEPT ALTERNATE
# Here probability value=4.67(4.67>0.05)
#H1:There is no significant difference between etest_p,mba_p
# So we accept null hypothesis and reject alternate hypothesis.

# %% [markdown]
# #QUESTION 8:Test the similariy between the degree_t(Sci&Tech)and specialisation(Mkt&HR)with respect
# #to salary significance level of 5%.(Decision using Hypothesis Testing)

# %%
#independent sample-unpaired TTest
#different group(degree_t(sci&Tech),specialisation(Mkt&HR)) but same condition(salary)
from scipy.stats import ttest_ind
dataset=dataset.dropna()
D=dataset[dataset["degree_t"]=="Sci&Tech"]["salary"]
S=dataset[dataset["specialisation"]=="Mkt&HR"]["salary"]
ttest_ind(D,S)
# Out:
# Ttest_indResult(statistic=2.692041243555374, pvalue=0.007897969943471179)

# %%
#statement: whether There is significant similarity between degree_t(sci&Tech) and specialisation(Mkt&HR) with salary?
#Ho:There is no significant similarity between degree_t(sci&Tech) and specialisation(Mkt&HR) with salary
#H1:There is significant similarity between degree_t(sci&Tech) and specialisation(Mkt&HR) with salary
#p value=0.007 which is <0.05
#condition :p<0.05,REJECT NULL HYPOTHESIS,ACCEPT ALTERNATE
# Here probability value=0.07(0.007<0.05)
#H1:There is significant similarity between degree_t(sci&Tech) and specialisation(Mkt&HR) with salary
# So we reject null hypothesis and accept alternate hypothesis.

# %% [markdown]
# #QUESTION 9:Convert the normal distribution to standard normal distribution for salary column

# %%
def stdNBgraph(dataset):
    #converting to std normal distribution
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()
    values=[i for i in dataset]
    z_score=[((j-mean)/std)for j in values]
    sns.distplot(z_score,kde=True)
    sum(z_score)/len(z_score)

# %%
stdNBgraph(dataset["salary"])
# Out:
# C:\Users\saran\anaconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# #QUESTION 10:What is the Probability Density Function of the salary range from 7 lakhs to 9 lakhs?

# %%
def get_pdf_probability(dataset,startrange,endrange):
    #importing needed libraries
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    #kde=kernal density fn.have to give kde=true.then only we can make curve.
    #mentioned below as curve line is blue,histogram color is green
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='green')
    # axis vertical line startrange color is red,endrange line color also red
    #startrange and endrange value getting from the user
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    #generate a sample
    sample = dataset
    #calculating mean and median 
    sample_mean =sample.mean()
    sample_std =sample.std()
    #printing the values of mean and median
    print('Mean=%.3f, Standard Deviation=%.3f' %(sample_mean, sample_std))
    #define the distribution
    #having default fn for norm
    #its learnig how to distribute from getting mean ,median values by using norm
    dist = norm(sample_mean, sample_std)
    #sample probabilities for a range pf outcomes
    #(values = []
    #for value in range(startrange, endrange):
       # values.append(value))
    #for the above method used the below oneliner for loop method
    values = [value for value in range(startrange, endrange)]
    #values converted by using pdf fn and transformed to probabilities
    probabilities = [dist.pdf(value) for value in values]
    #creaing summation for probabilities
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["salary"],700000,900000)
# Out:
# C:\Users\saran\anaconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Mean=198702.326, Standard Deviation=154780.927
# The area between range(700000,900000):0.0005973310593974868
# 0.0005973310593974868

# %%
#RESULT:There is 0.0005% Probability to get the salary range of 7 lakhs to 9 lakhs.

# %% [markdown]
# #QUESTION 11:Test the similariy between the degree_t(Sci&Tech)with respect
# to etest_p and mba_p at significance level of 5%.(Decision using by Hypothesis Testing)

# %%
#dependent sample-paired TTest
#same group(degree_t(sci&Tech)) but different condition(etest_p,mba_p)
from scipy.stats import ttest_rel
#dataset=dataset.dropna()
test=dataset[dataset["degree_t"]=="Sci&Tech"]["etest_p"]
test1=dataset[dataset["degree_t"]=="Sci&Tech"]["mba_p"]
ttest_rel(test,test1)
# Out:
# Ttest_relResult(statistic=5.0049844583693615, pvalue=5.517920600505392e-06)

# %%
#statement: whether There is significant similarity between etest_p and mba_p with degree_t(sci&Tech)?
#Ho:There is no significant similarity between etest_p and mba_p with degree_t(sci&Tech)
#H1:There is significant similarity between etest_p and mba_p with degree_t(sci&Tech)
#p value=5.51 which is >0.05
#condition :p<0.05,REJECT NULL HYPOTHESIS,ACCEPT ALTERNATE
#Ho:So,There is no significant similarity between degree_t(sci&Tech) and specialisation(Mkt&HR) with salary
# Here we accept null hypothesis and reject alternate hypothesis.

# %% [markdown]
# #QUESTION 12:Which parameter is highly correlated with salary?

# %%
dataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
#RESULT:There is no parameter is highly correlated with salary.all the parameters are zero correaltion
#        only.Among that the highest correlated with salary is ssc_p with 0.5% .

# %%
#QUESTION 13:plot any useful graph and explain it

# %%
import matplotlib.pyplot as plt
salary=dataset["salary"]
plt.plot(salary)
plt.title("SALARY DISTRIBUTION",color="orange")
plt.xlabel("STUDENTS",color="blue")
plt.ylabel("SALARY",color="green")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
